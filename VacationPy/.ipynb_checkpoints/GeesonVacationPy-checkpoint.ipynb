# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys1 import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat      Lng  Max Temp  Humidity  \
# 0        0                    florencia  43.7667  11.2500     23.53        82
# 1        1                    bharatpur  27.2167  77.4833     31.67        60
# 2        2                       namibe -15.1961  12.1522     19.23        54
# 3        3  edinburgh of the seven seas -37.0676 -12.3116     15.17        95
# 4        4                  west island -12.1568  96.8225     25.99        83
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        1.54      IT  2023-07-19
# 1          97        3.38      IN  2023-07-19
# 2           0        1.98      AO  2023-07-19
# 3         100        8.74      SH  2023-07-19
# 4          75        6.69      CC  2023-07-19

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot & display (referred to: https://hvplot.holoviz.org/user_guide/Geographic_Data.html and https://matplotlib.org/stable/gallery/lines_bars_and_markers/multivariate_marker_plot.html)
city_data_df.hvplot.points('Lng', 'Lat', geo=True, color='red', alpha=0.5, tiles='StamenWatercolor', s="Humidity")
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df_reduced = pd.DataFrame(city_data_df.loc[city_data_df['Humidity']<80,:])

city_data_df_red2 = pd.DataFrame(city_data_df_reduced.loc[(city_data_df_reduced['Max Temp']>=15) & (city_data_df_reduced['Max Temp']<=26)])

# Drop any rows with null values
city_data_df_red2.dropna()


# Display sample data
city_data_df_red2.head()
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 2         2          namibe -15.1961   12.1522     19.23        54
# 7         7        karratha -20.7377  116.8463     24.23        21
# 11       11  guerrero negro  27.9769 -114.0611     21.25        77
# 15       15    east ballina -28.8667  153.5833     20.44        59
# 16       16    saint-joseph -21.3667   55.6167     20.21        76
#
#     Cloudiness  Wind Speed Country        Date
# 2            0        1.98      AO  2023-07-19
# 7            2        5.48      AU  2023-07-19
# 11           5        8.44      MX  2023-07-19
# 15           0        6.97      AU  2023-07-19
# 16          18        6.51      RE  2023-07-19

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df_red2[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 2           namibe      AO -15.1961   12.1522        54
# 7         karratha      AU -20.7377  116.8463        21
# 11  guerrero negro      MX  27.9769 -114.0611        77
# 15    east ballina      AU -28.8667  153.5833        59
# 16    saint-joseph      RE -21.3667   55.6167        76

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
latitude = hotel_df["Lat"]
longitude = hotel_df["Lng"]

categories = "accommodation.hotel"
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    ThisLat = latitude[index]
    ThisLong = longitude[index]
    radius = 10000
    limit = 5

    filters = f"circle:{ThisLong},{ThisLat},{radius}"
    bias = f"proximity:{ThisLong},{ThisLat}"


    params = {
        "categories":categories,
        "limit":limit,
        "filter":filters,
        "bias":bias,
        "apiKey":geoapify_key  
    }

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
#     params["filter"] = 
#     params["bias"] = # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# namibe - nearest hotel: Hotel Chik Chik Namibe
# karratha - nearest hotel: Karratha International Hotel
# guerrero negro - nearest hotel: Plaza sal paraiso
# east ballina - nearest hotel: Ballina Beach Resort
# saint-joseph - nearest hotel: PALM Hotel & Spa
# khandyga - nearest hotel: Апельсин
# port mathurin - nearest hotel: Escale Vacances
# chinchilla - nearest hotel: Chinchilla Downtown Motor Inn
# sretensk - nearest hotel: No hotel found
# udachny - nearest hotel: Вилюй
# bilibino - nearest hotel: No hotel found
# tosontsengel - nearest hotel: Алтай
# ribeira grande - nearest hotel: Hospedaria JSF
# itaituba - nearest hotel: TG Hotel
# avarua - nearest hotel: Paradise Inn
# leh - nearest hotel: Kang Lha Chen
# klyuchi - nearest hotel: No hotel found
# flying fish cove - nearest hotel: Christmas Island Lodge
# kolyvan' - nearest hotel: No hotel found
# yeed - nearest hotel: No hotel found
# jamestown - nearest hotel: DoubleTree Jamestown
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %% [markdown]
# I have assumed that this means a map of the reduced selection, rather than the original map.
# If this is interpreted incorrectly, the code would instead be:
# city_data_df.hvplot.points('Lng', 'Lat', geo=True, color='red', alpha=0.5, tiles='StamenWatercolor', s="Humidity",\
# hover_cols=['Hotel Name'] )

# %%
# %%capture --no-display

# Configure the map plot & display map
hotel_df.hvplot.points('Lng', 'Lat', geo=True, color='red', alpha=0.5, tiles='StamenWatercolor', s="Humidity", hover_cols=['Hotel Name'] )
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Hotel Name)
